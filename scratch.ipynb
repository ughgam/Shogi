# %%
bool(0)
# Out:
# False

# %%
k=(0,6)
print(k[0])
print(k[1])
print(type(k))
# Out:
# 0
# 6
# <class 'tuple'>

# %%
#making an if and elif statement
a=int(input("Enter a number: "))
if a>0:
    print("a is positive")
elif a<0:
    print("a is negative")
# Out:
# a is negative
